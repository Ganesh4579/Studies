# %%
import matplotlib as mp
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv('/home/ganesh/Documents/seaborn-master/ComputerSales.csv')
df1.head(3)
# Out:
#    Sale ID      Contact Sex  Age State Product ID Product Type  Sale Price  \
# 0        1  Paul Thomas   M   43    OH  M01-F0024      Desktop      479.99
# 1        2  Margo Simms   F   37    WV  GT13-0024      Desktop     1249.99
# 2        3    Sam Stine   M   26    PA      I3670      Desktop      649.99
#
#    Profit     Lead     Month  Year
# 0  143.39  Website   January  2018
# 1  230.89  Flyer 4   January  2018
# 2  118.64  Website  February  2018

# %%
print(sns.get_dataset_names())
df=sns.load_dataset('car_crashes')
df
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# ...

# %%
sns.distplot(df['alcohol'])
plt.show()

# %%
sns.jointplot(x='speeding',y='alcohol',data=df)

# %%
sns.jointplot(x='speeding',y='alcohol',data=df,kind='reg')

# %%
sns.jointplot(x='speeding',y='alcohol',data=df,kind='kde')

# %%
sns.kdeplot(df['alcohol'])
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %%
sns.pairplot(df)
plt.show()

# %%
sns.rugplot(df['alcohol'])
# Out:
# <AxesSubplot:xlabel='alcohol'>

# %%
sns.barplot(x='Sex',y='Profit',data=df1,estimator=np.cov)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Profit'>

# %%
sns.countplot(x='Sex',data=df1)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.boxplot(x='Age',y='Profit',data=df1,hue='Sex')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Profit'>

# %%
sns.violinplot(x='Age',y='Profit',data=df1,hue='Sex')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Profit'>

# %%
sns.stripplot(x='Age',y='Profit',data=df1,hue='Sex',dodge=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Profit'>

# %%
sns.violinplot(x='Age',y='Profit',data=df1,hue='Sex')
sns.swarmplot(x='Age',y='Profit',data=df1,hue='Sex')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Profit'>

# %%
sns.set_style('dark')
sns.swarmplot(x='Age',y='Profit',data=df1,hue='Sex')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Profit'>

# %%
sns.set_style('dark')
sns.set_context('poster')
sns.swarmplot(x='Age',y='Profit',data=df1,hue='Sex')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Profit'>

# %%
df3=sns.load_dataset('iris')
df3.pop('species')

sns.clustermap(df3)

# %%
df2=sns.load_dataset('flights')
df2_p=df2.pivot(index='month',columns='year',values='passengers')
df2
sns.heatmap(df2_p)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.clustermap(df2_p)
